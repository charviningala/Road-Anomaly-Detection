# %% [markdown]
# # India dataset only - imgsize = 416, epochs 140

# %% [markdown]
# ### Yolov8n model

# %%
from pathlib import Path
import pandas as pd
import os

# %%
yolov8n_india = Path('/home/saber/GitHub/road_anomaly_detection/runs/standby_models/yolov8n2')

assert yolov8n_india.is_dir(), f'{yolov8n_india} is not a directory'

# %%
results_csv = yolov8n_india / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 135    136  1597.96         1.54422         1.23733         1.34650
# 136    137  1609.64         1.54370         1.22748         1.34293
# 137    138  1621.34         1.53533         1.21157         1.33439
# 138    139  1633.01         1.53819         1.23113         1.34231
# 139    140  1644.62         1.53121         1.21268         1.33208
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 135               0.55395            0.48655           0.47547
# 136               0.56375            0.47890           0.47681
# 137               0.56677            0.47161           0.47693
# 138               0.57686            0.46503           0.47665
# 139               0.55492            0.48057           0.47601
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 135              0.19707       2.06611       1.64229       1.69891  0.000091
# 136              0.19592       2.06734       1.64319       1.69742  0.000077
# 137              0.19694       2.06981       1.63526       1.70096  0.000062
# 138              0.19541       2.06944       1.63655       1.69606  0.000048
# 139              0.19542       2.07143       1.63964       1.69949  0.000034
#
#        lr/pg1    lr/pg2
# 135  0.000091  0.000091
# 136  0.000077  0.000077
# 137  0.000062  0.000062
# 138  0.000048  0.000048
# 139  0.000034  0.000034

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.5549
# Recall:    0.4806
# mAP@0.5:   0.4760
# mAP@0.5:0.95: 0.1954
# F1 Score:  0.5151

# %%
# Append result into pandas dataframe along with epochs and img size

# Create a new dataframe with the desired columns
df_metrics_india = pd.DataFrame(columns=[
    "Model",
    "ImgSize",
    "Epochs",
    "Precision",
    "Recall",
    "mAP50",
    "mAP50-95",
    "F1 Score"
])

# %%
df_metrics_india = df_metrics_india.append({
    "Model": "yolov8n",
    "ImgSize": 416,
    "Epochs": 140,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)
# Out:
# /tmp/ipykernel_46801/4221319525.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_india = df_metrics_india.append({

# %%
SAVE_DIR = Path("/home/saber/GitHub/road_anomaly_detection/runs/metrics_comparison")
os.makedirs(SAVE_DIR, exist_ok=True)
df_metrics_india.to_csv(SAVE_DIR / "metrics_india.csv", index=False)

# %% [markdown]
# ### Yolov8s model

# %%
yolov8s_india = Path('/home/saber/GitHub/road_anomaly_detection/runs/standby_models/yolov8s')

assert yolov8s_india.is_dir(), f'{yolov8s_india} is not a directory'

# %%
results_csv = yolov8s_india / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 135    136  2329.56         1.33181         0.95018         1.23790
# 136    137  2346.63         1.32722         0.92980         1.23246
# 137    138  2363.70         1.33183         0.92799         1.23256
# 138    139  2380.78         1.32639         0.93975         1.23314
# 139    140  2397.76         1.31411         0.91897         1.22075
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 135               0.53877            0.47339           0.47671
# 136               0.55481            0.46482           0.47627
# 137               0.55874            0.46324           0.47534
# 138               0.55923            0.46413           0.47363
# 139               0.54631            0.46929           0.47555
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 135              0.19603       2.18790       1.64278       1.84407  0.000091
# 136              0.19519       2.18773       1.63924       1.85047  0.000077
# 137              0.19570       2.19285       1.65420       1.85217  0.000062
# 138              0.19406       2.19446       1.65793       1.85349  0.000048
# 139              0.19466       2.19433       1.65530       1.85311  0.000034
#
#        lr/pg1    lr/pg2
# 135  0.000091  0.000091
# 136  0.000077  0.000077
# 137  0.000062  0.000062
# 138  0.000048  0.000048
# 139  0.000034  0.000034

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.5463
# Recall:    0.4693
# mAP@0.5:   0.4755
# mAP@0.5:0.95: 0.1947
# F1 Score:  0.5049

# %%
df_metrics_india = df_metrics_india.append({
    "Model": "yolov8s",
    "ImgSize": 416,
    "Epochs": 140,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_india.to_csv(SAVE_DIR / "metrics_india.csv", index=False)
# Out:
# /tmp/ipykernel_46801/540023886.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_india = df_metrics_india.append({

# %% [markdown]
# # Yolov8m model

# %%
yolov8m_india = Path('/home/saber/GitHub/road_anomaly_detection/runs/standby_models/yolov8m3')

assert yolov8m_india.is_dir(), f'{yolov8m_india} is not a directory'

# %%
results_csv = yolov8m_india / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 135    136  5783.07         1.41251         1.11283         1.42327
# 136    137  5825.60         1.43057         1.09950         1.43648
# 137    138  5868.06         1.41630         1.10332         1.42549
# 138    139  5910.32         1.42616         1.09922         1.43274
# 139    140  5952.99         1.40659         1.07161         1.41476
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 135               0.55521            0.43754           0.45701
# 136               0.57063            0.43770           0.46089
# 137               0.56565            0.44292           0.46657
# 138               0.56598            0.44819           0.46516
# 139               0.54641            0.44787           0.46240
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 135              0.18730       2.12894       1.64287       2.00380  0.000091
# 136              0.18860       2.12840       1.64671       2.01080  0.000077
# 137              0.18858       2.12687       1.64079       2.01040  0.000062
# 138              0.18740       2.12741       1.63769       2.01080  0.000048
# 139              0.18633       2.13113       1.64139       2.01363  0.000034
#
#        lr/pg1    lr/pg2
# 135  0.000091  0.000091
# 136  0.000077  0.000077
# 137  0.000062  0.000062
# 138  0.000048  0.000048
# 139  0.000034  0.000034

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.5464
# Recall:    0.4479
# mAP@0.5:   0.4624
# mAP@0.5:0.95: 0.1863
# F1 Score:  0.4923

# %%
df_metrics_india = df_metrics_india.append({
    "Model": "yolov8m",
    "ImgSize": 416,
    "Epochs": 140,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_india.to_csv(SAVE_DIR / "metrics_india.csv", index=False)
# Out:
# /tmp/ipykernel_46801/2271626599.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_india = df_metrics_india.append({

# %%
df_metrics_india.head()
# Out:
#      Model ImgSize Epochs  Precision   Recall    mAP50  mAP50-95  F1 Score
# 0  yolov8n     416    140    0.55492  0.48057  0.47601   0.19542  0.515076
# 1  yolov8s     416    140    0.54631  0.46929  0.47555   0.19466  0.504880
# 2  yolov8m     416    140    0.54641  0.44787  0.46240   0.18633  0.492257

# %% [markdown]
# # Models trained on 3 countries - Japan/Czech/India - imgsize 640; epochs - 70

# %% [markdown]
# ### Yolov8n

# %%
yolov8n8_three_country = Path("../../runs/three_country_training/road_defect_binary/yolov8n8")

assert yolov8n8_three_country.is_dir(), f'{yolov8n8_three_country} is not a directory'

# %%
results_csv = yolov8n8_three_country / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66  5465.81         1.50227         1.25322         1.45395
# 66     67  5547.69         1.49450         1.24388         1.45053
# 67     68  5629.30         1.48954         1.23962         1.44464
# 68     69  5711.12         1.48346         1.22828         1.44224
# 69     70  5792.84         1.47469         1.22075         1.43554
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.65931            0.57813           0.62764
# 66               0.65922            0.57595           0.62672
# 67               0.65290            0.57994           0.62563
# 68               0.64818            0.58367           0.62636
# 69               0.64564            0.58207           0.62646
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.31609       1.73017       1.40831       1.59114  0.002421
# 66              0.31552       1.73298       1.40825       1.59303  0.001997
# 67              0.31513       1.73595       1.40770       1.59521  0.001573
# 68              0.31499       1.73901       1.40696       1.59753  0.001149
# 69              0.31510       1.74035       1.40673       1.59881  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.6456
# Recall:    0.5821
# mAP@0.5:   0.6265
# mAP@0.5:0.95: 0.3151
# F1 Score:  0.6122

# %%
# Append result into pandas dataframe along with epochs and img size

# Create a new dataframe with the desired columns
df_metrics_3_country = pd.DataFrame(columns=[
    "Model",
    "ImgSize",
    "Epochs",
    "Precision",
    "Recall",
    "mAP50",
    "mAP50-95",
    "F1 Score"
])

# %%
df_metrics_3_country = df_metrics_3_country.append({
    "Model": "yolov8n8",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_3_country.to_csv(SAVE_DIR / "metrics_three_country.csv", index=False)
# Out:
# /tmp/ipykernel_46801/2466828297.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_3_country = df_metrics_3_country.append({

# %% [markdown]
# ### Yolov8s

# %%
yolov8s_three_country = Path("../../runs/three_country_training/road_defect_binary/yolov8s")

assert yolov8s_three_country.is_dir(), f'{yolov8s_three_country} is not a directory'

# %%
results_csv = yolov8s_three_country / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 54     55  8310.47         1.44775         1.20609         1.38786
# 55     56  8459.75         1.43473         1.18706         1.38096
# 56     57  8608.94         1.42691         1.17433         1.38005
# 57     58  8758.06         1.42570         1.17637         1.37440
# 58     59  8907.45         1.41542         1.14442         1.36548
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 54               0.67793            0.59461           0.63922
# 55               0.67191            0.59736           0.63972
# 56               0.66991            0.59494           0.63655
# 57               0.67130            0.59721           0.63825
# 58               0.67287            0.59698           0.63692
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 54              0.32355       1.74512       1.34090       1.60937  0.007089
# 55              0.32387       1.74822       1.34028       1.61283  0.006664
# 56              0.32247       1.75140       1.33822       1.61638  0.006240
# 57              0.32158       1.75569       1.33935       1.61882  0.005816
# 58              0.32182       1.76031       1.33967       1.62397  0.005391
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 54  0.002363  0.007089  0.002363  0.007089  0.002363  0.007089  0.002363
# 55  0.002221  0.006664  0.002221  0.006664  0.002221  0.006664  0.002221
# 56  0.002080  0.006240  0.002080  0.006240  0.002080  0.006240  0.002080
# 57  0.001939  0.005816  0.001939  0.005816  0.001939  0.005816  0.001939
# 58  0.001797  0.005391  0.001797  0.005391  0.001797  0.005391  0.001797

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.6729
# Recall:    0.5970
# mAP@0.5:   0.6369
# mAP@0.5:0.95: 0.3218
# F1 Score:  0.6327

# %%
df_metrics_3_country = df_metrics_3_country.append({
    "Model": "yolov8s",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_3_country.to_csv(SAVE_DIR / "metrics_three_country.csv", index=False)
# Out:
# /tmp/ipykernel_46801/4123960304.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_3_country = df_metrics_3_country.append({

# %% [markdown]
# # Yolov8m

# %%
yolov8m_three_country = Path("../../runs/three_country_training/road_defect_binary/yolov8m")

assert yolov8m_three_country.is_dir(), f'{yolov8m_three_country} is not a directory'

# %%
results_csv = yolov8m_three_country / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 59     60  10241.9         1.44445         1.18318         1.33823
# 60     61  10411.3         1.44205         1.09905         1.35250
# 61     62  10581.0         1.42572         1.07858         1.34089
# 62     63  10750.5         1.41005         1.05689         1.33271
# 63     64  10919.8         1.40050         1.03736         1.32850
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 59               0.66125            0.57522           0.62649
# 60               0.67169            0.56822           0.62746
# 61               0.66377            0.57324           0.62538
# 62               0.66646            0.57236           0.62548
# 63               0.66187            0.57332           0.62346
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 59              0.31581       1.75422       1.30833       1.56956  0.004967
# 60              0.31578       1.75501       1.30509       1.57100  0.004543
# 61              0.31481       1.75856       1.30490       1.57328  0.004119
# 62              0.31413       1.76414       1.30552       1.57862  0.003694
# 63              0.31257       1.76998       1.30855       1.58538  0.003270
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 59  0.001656  0.004967  0.001656  0.004967  0.001656  0.004967  0.001656
# 60  0.001514  0.004543  0.001514  0.004543  0.001514  0.004543  0.001514
# 61  0.001373  0.004119  0.001373  0.004119  0.001373  0.004119  0.001373
# 62  0.001231  0.003694  0.001231  0.003694  0.001231  0.003694  0.001231
# 63  0.001090  0.003270  0.001090  0.003270  0.001090  0.003270  0.001090

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.6619
# Recall:    0.5733
# mAP@0.5:   0.6235
# mAP@0.5:0.95: 0.3126
# F1 Score:  0.6144

# %%
df_metrics_3_country = df_metrics_3_country.append({
    "Model": "yolov8m",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_3_country.to_csv(SAVE_DIR / "metrics_three_country.csv", index=False)
# Out:
# /tmp/ipykernel_46801/4293226768.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_3_country = df_metrics_3_country.append({

# %% [markdown]
# # Yolov26s  - For edge devices

# %%
yolov26s_three_country = Path("../../runs/three_country_training/road_defect_binary/yolov26s2")

assert yolov26s_three_country.is_dir(), f'{yolov26s_three_country} is not a directory'

# %%
results_csv = yolov26s_three_country / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66   9623.04         1.61993         1.33204         0.01535
# 66     67   9766.77         1.62313         1.32029         0.01535
# 67     68   9910.59         1.61725         1.31991         0.01534
# 68     69  10054.10         1.61060         1.30703         0.01514
# 69     70  10197.90         1.60419         1.29961         0.01501
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.64572            0.54970           0.60056
# 66               0.64259            0.55335           0.60067
# 67               0.64209            0.55160           0.60030
# 68               0.64201            0.55335           0.59995
# 69               0.64534            0.55224           0.59969
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.30062       1.78871       1.51391       0.01800  0.002421
# 66              0.30008       1.79219       1.51428       0.01806  0.001997
# 67              0.30030       1.79214       1.51910       0.01809  0.001573
# 68              0.29954       1.79637       1.51739       0.01815  0.001149
# 69              0.29912       1.80010       1.51563       0.01820  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.6453
# Recall:    0.5522
# mAP@0.5:   0.5997
# mAP@0.5:0.95: 0.2991
# F1 Score:  0.5952

# %%
df_metrics_3_country = df_metrics_3_country.append({
    "Model": "yolov26s",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_3_country.to_csv(SAVE_DIR / "metrics_three_country.csv", index=False)
# Out:
# /tmp/ipykernel_46801/2028041926.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_3_country = df_metrics_3_country.append({

# %% [markdown]
# # Fine tuned models on RD2022 Dataset

# %% [markdown]
# ## Img size = 640; epochs = 70

# %% [markdown]
# ### Yolov8n_rdd_2022

# %%
yolov8n_rdd_2022 = Path("../../runs/detect/yolov8n8_rdd2022_2class5")

assert yolov8n_rdd_2022.is_dir(), f'{yolov8n_rdd_2022} is not a directory'

# %%
results_csv = yolov8n_rdd_2022 / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66  7117.03         1.41404         1.27335         1.35869
# 66     67  7220.99         1.40713         1.25756         1.34859
# 67     68  7325.06         1.40324         1.25454         1.34827
# 68     69  7429.21         1.39606         1.24973         1.34479
# 69     70  7533.28         1.39394         1.25257         1.34420
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.64895            0.59126           0.64586
# 66               0.65012            0.59346           0.64650
# 67               0.64992            0.59332           0.64689
# 68               0.65125            0.59278           0.64765
# 69               0.65193            0.59427           0.64787
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.35797       1.53976       1.33769       1.42266  0.002421
# 66              0.35835       1.53897       1.33633       1.42197  0.001997
# 67              0.35838       1.53828       1.33427       1.42159  0.001573
# 68              0.35916       1.53773       1.33281       1.42120  0.001149
# 69              0.35943       1.53713       1.33127       1.42053  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.6519
# Recall:    0.5943
# mAP@0.5:   0.6479
# mAP@0.5:0.95: 0.3594
# F1 Score:  0.6218

# %%
# Append result into pandas dataframe along with epochs and img size

# Create a new dataframe with the desired columns
df_metrics_rd2022 = pd.DataFrame(columns=[
    "Model",
    "ImgSize",
    "Epochs",
    "Precision",
    "Recall",
    "mAP50",
    "mAP50-95",
    "F1 Score"
])

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8n",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/3912372812.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({

# %% [markdown]
# #### Yolov8s_rdd_2022

# %%
yolov8s_rdd_2022 = Path("../../runs/detect/yolov8s_rdd2022_2class7")

assert yolov8s_rdd_2022.is_dir(), f'{yolov8s_rdd_2022} is not a directory'

# %%
results_csv = yolov8s_rdd_2022 / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66  12108.5         1.18535         0.91195         1.21542
# 66     67  12289.9         1.17909         0.89206         1.20933
# 67     68  12470.9         1.16900         0.88675         1.20518
# 68     69  12652.0         1.16216         0.87994         1.20153
# 69     70  12832.7         1.16082         0.88446         1.20028
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.74361            0.69247           0.75794
# 66               0.74380            0.69269           0.75884
# 67               0.74305            0.69563           0.75986
# 68               0.74461            0.69614           0.76101
# 69               0.74527            0.69789           0.76196
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.45779       1.39958       1.04084       1.33409  0.002421
# 66              0.45883       1.39827       1.03831       1.33283  0.001997
# 67              0.45901       1.39696       1.03582       1.33174  0.001573
# 68              0.45975       1.39556       1.03353       1.33080  0.001149
# 69              0.46057       1.39449       1.03091       1.32993  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.7453
# Recall:    0.6979
# mAP@0.5:   0.7620
# mAP@0.5:0.95: 0.4606
# F1 Score:  0.7208

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8s",
    "ImgSize": 640,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/2333915480.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({

# %% [markdown]
# ## Img size = 256; epochs = 70

# %% [markdown]
# #### Yolov8n8

# %%
yolov8n8_rdd_2022_256 = Path("../../runs/detect/yolov8n8_rdd2022_2class_256")

assert yolov8n8_rdd_2022_256.is_dir(), f'{yolov8n8_rdd_2022_256} is not a directory'

# %%
results_csv = yolov8n8_rdd_2022_256 / "results.csv"
assert results_csv.exists(), "results.csv not found!"

df = pd.read_csv(results_csv)
df.tail()
# Out:
#     epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 65     66  2880.29         1.87888         1.72889         1.35528
# 66     67  2922.89         1.86749         1.71349         1.34824
# 67     68  2965.88         1.86385         1.70676         1.34648
# 68     69  3008.38         1.86426         1.70463         1.34615
# 69     70  3052.19         1.86078         1.70464         1.34546
#
#     metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 65               0.45719            0.35135           0.34099
# 66               0.45817            0.35193           0.34230
# 67               0.45945            0.35304           0.34238
# 68               0.45904            0.35377           0.34243
# 69               0.46088            0.35268           0.34300
#
#     metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 65              0.15698       1.93649       1.80312       1.36284  0.002421
# 66              0.15721       1.93569       1.80194       1.36214  0.001997
# 67              0.15722       1.93532       1.80066       1.36168  0.001573
# 68              0.15743       1.93513       1.79933       1.36109  0.001149
# 69              0.15745       1.93476       1.79798       1.36062  0.000724
#
#       lr/pg1    lr/pg2    lr/pg3    lr/pg4    lr/pg5    lr/pg6    lr/pg7
# 65  0.000807  0.002421  0.000807  0.002421  0.000807  0.002421  0.000807
# 66  0.000666  0.001997  0.000666  0.001997  0.000666  0.001997  0.000666
# 67  0.000524  0.001573  0.000524  0.001573  0.000524  0.001573  0.000524
# 68  0.000383  0.001149  0.000383  0.001149  0.000383  0.001149  0.000383
# 69  0.000241  0.000724  0.000241  0.000724  0.000241  0.000724  0.000241

# %%
final = df.iloc[-1]

print("Final metrics:")
print(f"Precision: {final['metrics/precision(B)']:.4f}")
print(f"Recall:    {final['metrics/recall(B)']:.4f}")
print(f"mAP@0.5:   {final['metrics/mAP50(B)']:.4f}")
print(f"mAP@0.5:0.95: {final['metrics/mAP50-95(B)']:.4f}")


# f1 score
precision = final['metrics/precision(B)']
recall = final['metrics/recall(B)']
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print(f"F1 Score:  {f1_score:.4f}")
# Out:
# Final metrics:
# Precision: 0.4609
# Recall:    0.3527
# mAP@0.5:   0.3430
# mAP@0.5:0.95: 0.1575
# F1 Score:  0.3996

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8n8",
    "ImgSize": 256,
    "Epochs": 70,
    "Precision": final['metrics/precision(B)'],
    "Recall": final['metrics/recall(B)'],
    "mAP50": final['metrics/mAP50(B)'],
    "mAP50-95": final['metrics/mAP50-95(B)'],
    "F1 Score": f1_score
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/3147937652.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({

# %% [markdown]
# # Quantized Model - Yolov8n 320x320

# %%
from ultralytics import YOLO

yolov8_320_int8 = YOLO("/home/saber/GitHub/road_anomaly_detection/runs/detect/yolov8n8_rdd2022_2class5/weights/best_saved_model/best_full_integer_quant.tflite")

metrics = yolov8_320_int8.val(
    data="/home/saber/GitHub/road_anomaly_detection/data/rdd2class_yolo/rdd2class.yaml",
    imgsz=320
)

print(f"metrics.box.map: {metrics.box.map}")      # mAP50-95
print(f"metrics.box.map50: {metrics.box.map50}")    # mAP50
print(f"metrics.box.mp: {metrics.box.mp}")       # Precision
print(f"metrics.box.mr: {metrics.box.mr}")       # Recall
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7799MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771323571.553033   46801 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771323571.565360   46801 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771323571.594148   46801 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771323571.594197   46801 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771323571.594204   46801 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771323571.594207   46801 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Loading /home/saber/GitHub/road_anomaly_detection/runs/detect/yolov8n8_rdd2022_2class5/weights/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 320, 320)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 201.5±92.5 MB/s, size: 123.5 KB)
# val: Scanning /home/saber/GitHub/road_anomaly_detection/data/rdd2class_yolo/labels/val.cache... 5120 images, 1670 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5120/5120 650.8Mit/s 0.0s
# /home/saber/GitHub/road_anomaly_detection/.venv/lib/python3.12/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5120/5120 77.2it/s 1:06<0.0ss
#                    all       5120       7177      0.405      0.318       0.29      0.121
#                  crack       3205       6116      0.447      0.338      0.331      0.143
#                pothole        644       1061      0.362      0.299      0.249     0.0994
# Speed: 0.1ms preprocess, 9.5ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/saber/GitHub/road_anomaly_detection/runs/detect/val4
# metrics.box.map: 0.12138216015280967
# metrics.box.map50: 0.2898478918086408
# metrics.box.mp: 0.40474514276407947
# metrics.box.mr: 0.31834477588657634

# %%
precision = metrics.box.mp
recall = metrics.box.mr

f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print("F1:", f1)
# Out:
# F1: 0.3563830678343654

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8n Quantized (int8)",
    "ImgSize": 320,
    "Epochs": 70,
    "Precision": precision,
    "Recall": recall,
    "mAP50": metrics.box.map50,
    "mAP50-95": metrics.box.map,
    "F1 Score": f1
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/1160912964.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({

# %% [markdown]
# # Quantized Model - Yolov8n 256x256

# %%
from ultralytics import YOLO

model = YOLO("../../runs/detect/yolov8n8_rdd2022_2class_256/weights/best_saved_model/best_full_integer_quant.tflite")

metrics = model.val(
    data="../../data/rdd2class_yolo/rdd2class.yaml",
    imgsz=256
)

print(f"metrics.box.map: {metrics.box.map}")      # mAP50-95
print(f"metrics.box.map50: {metrics.box.map50}")    # mAP50
print(f"metrics.box.mp: {metrics.box.mp}")       # Precision
print(f"metrics.box.mr: {metrics.box.mr}")       # Recall
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7799MiB)
# Loading ../../runs/detect/yolov8n8_rdd2022_2class_256/weights/best_saved_model/best_full_integer_quant.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 256, 256)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5103.4±1772.1 MB/s, size: 100.2 KB)
# val: Scanning /home/saber/GitHub/road_anomaly_detection/data/rdd2class_yolo/labels/val.cache... 5120 images, 1670 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5120/5120 2.1Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5120/5120 121.7it/s 42.1s<0.1s
#                    all       5120       7177      0.244      0.103       0.17     0.0874
#                  crack       3205       6116      0.488      0.205       0.34      0.175
#                pothole        644       1061          0          0          0          0
# Speed: 0.1ms preprocess, 6.3ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/saber/GitHub/road_anomaly_detection/runs/detect/val6
# metrics.box.map: 0.08741284848560811
# metrics.box.map50: 0.17000400432328633
# metrics.box.mp: 0.24397356143079316
# metrics.box.mr: 0.1025997383911053

# %%
precision = metrics.box.mp
recall = metrics.box.mr

f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print("F1:", f1)
# Out:
# F1: 0.1444521178637201

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8n Quantized (int8)",
    "ImgSize": 256,
    "Epochs": 70,
    "Precision": precision,
    "Recall": recall,
    "mAP50": metrics.box.map50,
    "mAP50-95": metrics.box.map,
    "F1 Score": f1
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/3831439824.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({

# %% [markdown]
# # Quantized model - Yolov8n - 256x256 nms

# %%
from ultralytics import YOLO

model = YOLO("../../runs/detect/yolov8n8_rdd2022_2class_256/weights/best_saved_model/best_int8.tflite")

metrics = model.val(
    data="../../data/rdd2class_yolo/rdd2class.yaml",
    imgsz=256
)

print(f"metrics.box.map: {metrics.box.map}")      # mAP50-95
print(f"metrics.box.map50: {metrics.box.map50}")    # mAP50
print(f"metrics.box.mp: {metrics.box.mp}")       # Precision
print(f"metrics.box.mr: {metrics.box.mr}")       # Recall
# Out:
# Ultralytics 8.4.9 🚀 Python-3.12.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 7799MiB)
# Loading ../../runs/detect/yolov8n8_rdd2022_2class_256/weights/best_saved_model/best_int8.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 256, 256)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4628.3±2429.8 MB/s, size: 91.6 KB)
# val: Scanning /home/saber/GitHub/road_anomaly_detection/data/rdd2class_yolo/labels/val.cache... 5120 images, 1670 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5120/5120 2.7Git/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 0% ──────────── 12/5120 34.7it/s 0.1s<2:27
# /home/saber/GitHub/road_anomaly_detection/.venv/lib/python3.12/site-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5120/5120 125.1it/s 40.9s<0.1s
#                    all       5120       7177      0.575      0.252      0.417      0.221
#                  crack       3205       6116      0.592      0.277      0.432      0.232
#                pothole        644       1061      0.558      0.227      0.401       0.21
# Speed: 0.1ms preprocess, 5.9ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/saber/GitHub/road_anomaly_detection/runs/detect/val7
# metrics.box.map: 0.2212480700120918
# metrics.box.map50: 0.416720877997122
# metrics.box.mp: 0.5750957436494086
# metrics.box.mr: 0.25230656876264046

# %%
precision = metrics.box.mp
recall = metrics.box.mr

f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
print("F1:", f1)
# Out:
# F1: 0.35073731753826876

# %%
df_metrics_rd2022 = df_metrics_rd2022.append({
    "Model": "yolov8n Quantized (int8, nms)",
    "ImgSize": 256,
    "Epochs": 70,
    "Precision": precision,
    "Recall": recall,
    "mAP50": metrics.box.map50,
    "mAP50-95": metrics.box.map,
    "F1 Score": f1
}, ignore_index=True)

# Save the updated dataframe to CSV
df_metrics_rd2022.to_csv(SAVE_DIR / "metrics_rd2022.csv", index=False)
# Out:
# /tmp/ipykernel_46801/3517248908.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_metrics_rd2022 = df_metrics_rd2022.append({
